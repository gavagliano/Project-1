# %%
import requests
import json
import pandas as pd

# %%
url = "https://api.foursquare.com/v3/places/search?categories=13034%2C13035&exclude_all_chains=true&fields=name%2Chours%2Cgeocodes%2Clocation%2Cdate_closed%2Cdescription%2Cfeatures&open_at=1T2300&near=New%20York%2C%20NY&limit=50"

headers = {
    "accept": "application/json",
    "Authorization": "fsq3+i9wQXUHtAvYAUtJzPszGzJjz69anbZluHb3N2tdusM="
}

response = requests.get(url, headers=headers)
data = response.json()

# %%
for case in data["results"]:
    print(case['name'])
# Out:
# Kobrick Coffee Co
# La Lanterna di Vittorio
# The Uncommons
# Hi-Collar
# Mudspot
# The Roost
# Amorino
# Cafe Habana
# Bread & Butter
# Pasticceria Rocco
# Cafe Gitane
# Dudley's
# Murray Hill Market
# Nuyorican Poets Cafe
# Café Select
# The Grey Dog
# Epistrophy
# Vin Sur Vingt
# Café Standard
# Banc Cafe
# Caffe Reggio
# B'Artusi
# Sweet Rehab
# V-Nam Cafe
# Peter McManus Cafe
# Mansion Restaurant
# Radio Star
# Kind Regards
# Vintage
# Round K by Sol
# Cafe 53
# Bar Veloce
# Shade
# Cafe Un Deux Trois
# Caffe Palermo
# Split Eights
# Stafili Wine Cafe
# Five & Dime
# The Flame Diner
# Viand Cafe
# Think Coffee
# Red Flame Coffee Shop
# Cafe Amrita
# ABC Cafeteria
# Amore Pizza Cafe
# Festivál
# Europan Cafe
# Monkey Room
# Aziza Cafe & Lounge
# Edgar's Cafe

# %%
list = []
for case in data["results"]:
    dict = {}
    dict['name'] = case['name']
    dict['latitude'] = case['geocodes']['main']['latitude']
    dict['longitude'] = case['geocodes']['main']['longitude']
    dict['hours'] = case['hours']['display']
    
    list.append(dict)
print(list)
# Out:
# [{'name': 'Kobrick Coffee Co', 'latitude': 40.740378, 'longitude': -74.005485, 'hours': 'Mon-Fri 12:00 AM-2:00 AM, 7:00 AM-11:59 PM; Sat-Sun 12:00 AM-2:00 AM, 8:00 AM-11:59 PM'}, {'name': 'La Lanterna di Vittorio', 'latitude': 40.730705, 'longitude': -74.000125, 'hours': 'Mon-Fri 12:00 AM-2:00 AM; Sat-Sun 12:00 AM-3:00 AM'}, {'name': 'The Uncommons', 'latitude': 40.729342, 'longitude': -73.998674, 'hours': 'Mon-Fri 8:30 AM-11:59 PM; Sat 12:00 AM-1:00 AM, 8:30 AM-11:59 PM; Sun 12:00 AM-1:00 AM, 8:30 AM-11:00 PM'}, {'name': 'Hi-Collar', 'latitude': 40.729199, 'longitude': -73.986051, 'hours': 'Mon-Fri 12:00 AM-12:30 AM, 11:00 AM-5:00 PM, 6:00 PM-11:59 PM; Sat-Sun 12:00 AM-11:59 PM'}, {'name': 'Mudspot', 'latitude': 40.729074, 'longitude': -73.986657, 'hours': 'Mon-Fri 7:30 AM-11:59 PM; Sat-Sun 8:00 AM-11:59 PM'}, {'name': 'The Roost', 'latitude': 
293, 'longitude': -73.979529, 'hours': 'Open Daily 12:00 AM-3:59 AM'}, {'name': 'Caffe Reggio', 'latitude': 40.730265, 'longitude': -74.000457, 'hours': 'Mon-Fri 12:00 AM-3:00 AM, 8:00 AM-11:59 PM; Sat-Sun 12:00 AM-4:30 AM, 8:00 AM-11:59 PM'}, {'name': "B'Artusi", 'latitude': 40.733947, 'longitude': -74.005886, 'hours': 'Mon-Fri 12:00 PM-11:59 PM; Sat-Sun 12:00 AM-11:59 PM'}, {'name': 'Sweet Rehab', 'latitude': 40.726668, 'longitude': -74.001799, 'hours': 'Mon 6:00 PM-11:45 PM; Tue 3:00 PM-11:45 PM; Wed 12:00 PM-11:45 PM; Thu 9:00 AM-11:45 PM; Fri 10:00 AM-11:45 PM; Sat 9:00 AM-11:45 PM; Sun 10:00 AM-11:45 PM'}, {'name': 'V-Nam Cafe', 'latitude': 40.723536, 'longitude': -73.988012, 'hours': 'Mon-Fri 11:00 AM-11:59 PM; Sat-Sun 12:00 AM-2:00 AM'}, {'name': 'Peter McManus Cafe', 'latitude': 40.741834, 'longitude': -73.997551, 'hours': 'Open Daily 12:00 AM-4:00 AM'}, {'name': 'Mansion Restaurant', 'latitude': 40.776008, 'longitude': -73.946807, 'hours': 'Mo ...

# %%
df = pd.DataFrame(list)

# %%
df
# Out:
#                        name   latitude  longitude  \
# 0         Kobrick Coffee Co  40.740378 -74.005485
# 1   La Lanterna di Vittorio  40.730705 -74.000125
# 2             The Uncommons  40.729342 -73.998674
# 3                 Hi-Collar  40.729199 -73.986051
# 4                   Mudspot  40.729074 -73.986657
# 5                 The Roost  40.729131 -73.978583
# 6                   Amorino  40.759452 -73.988548
# 7               Cafe Habana  40.722990 -73.994233
# 8            Bread & Butter  40.743639 -73.972686
# 9         Pasticceria Rocco  40.730854 -74.002576
# 10              Cafe Gitane  40.723194 -73.994677
# 11                 Dudley's  40.717967 -73.990499
# 12       Murray Hill Market  40.746151 -73.979597
# 13     Nuyorican Poets Cafe  40.721979 -73.981752
# 14              Café Select  40.721813 -73.997853
# 15             The Grey Dog  40.722950 -73.995715
# 16               Epistrophy  40.721177 -73.995427
# 17            Vin Sur Vingt  40.784916 -73.972938
# 18            Café Standard  40.727776 -73.990798
# 19                Banc Cafe  40.743293 -73.979529
# 20             Caffe Reggio  40.730265 -74.000457
# 21                 B'Artusi  40.733947 -74.005886
# 22              Sweet Rehab  40.726668 -74.001799
# 23               V-Nam Cafe  40.723536 -73.988012
# 24       Peter McManus Cafe  40.741834 -73.997551
# 25       Mansion Restaurant  40.776008 -73.946807
# 26               Radio Star  40.749471 -73.984531
# 27             Kind Regards  40.720847 -73.987732
# 28                  Vintage  40.779320 -73.915556
# 29           Round K by Sol  40.715088 -73.993267
# 30                  Cafe 53  40.761787 -73.980033
# 31               Bar Veloce  40.730696 -73.986546
# 32                    Shade  40.729864 -73.999306
# 26  Mon 3:00 PM-11:59 PM; Tue-Thu 12:00 AM-2:00 AM...
# 27  Mon 4:00 PM-11:59 PM; Tue 12:00 AM-2:00 AM; We...
# 28  Mon-Thu 11:00 AM-11:30 PM; Fri 11:00 AM-11:59 ...
# 29  Mon 9:30 AM-4:00 PM, 5:00 PM-12:00 AM; Tue-Wed...
# 30                       Open Daily 12:00 AM-11:59 PM
# 31                        Open Daily 12:00 AM-3:00 AM
# 32                        Open Daily 12:00 AM-4:00 AM
# 33                        Open Daily 7:00 AM-11:59 PM
# 34                       Open Daily 10:30 AM-11:30 PM
# 35  Open Daily 12:00 AM-2:00 AM, 8:00 AM-3:00 PM, ...
# 36                       Open Daily 11:00 AM-11:59 PM
# 37      Mon-Sat 7:00 AM-11:59 PM; Sun 9:00 AM-4:00 PM
# 38                       Open Daily 12:00 AM-11:59 PM
# 39                        Open Daily 7:00 AM-11:59 PM
# 40  Mon-Fri 7:00 AM-11:59 PM; Sat-Sun 7:30 AM-11:5...
# 41                        Open Daily 6:30 AM-11:30 PM
# 42                        Open Daily 8:00 AM-11:30 PM
# 43                       Open Daily 12:00 AM-11:59 PM
# 44  Mon-Fri 12:00 AM-2:00 AM; Sat-Sun 12:00 AM-4:0...
# 45  Mon-Thu 8:00 AM-11:59 PM; Fri 10:00 AM-11:59 P...
# 46                       Open Daily 12:00 AM-11:59 PM
# 47                        Open Daily 12:00 AM-4:00 AM
# 48  Mon-Fri 12:00 AM-3:00 AM; Sat-Sun 12:00 AM-4:3...
# 49  Mon-Fri 8:00 AM-11:59 PM; Sat-Sun 12:00 AM-1:0...

# %%
df.to_csv("//Users//gianaavagliano//Desktop//df_project1_part2.csv")

# %%
for cafe in data['results']:
    if 'amenities' in cafe['features']:
        if 'wifi' in cafe['features']['amenities']:
            if cafe['features']['amenities']['wifi'] == 't':
                print(cafe['name'], "has wifi.")
            if cafe['features']['amenities']['wifi'] == 'f':
                print(cafe['name'], "has free wifi.")
    else:
        print("No amenities")
# Out:
# Kobrick Coffee Co has wifi.
# The Uncommons has free wifi.
# The Roost has free wifi.
# Amorino has wifi.
# No amenities
# Cafe Gitane has wifi.
# No amenities
# Epistrophy has wifi.
# Café Standard has wifi.
# Caffe Reggio has wifi.
# No amenities
# No amenities
# Radio Star has free wifi.
# No amenities
# No amenities
# Cafe Un Deux Trois has wifi.
# No amenities
# No amenities
# No amenities
# Think Coffee has wifi.
# Cafe Amrita has wifi.
# No amenities
# No amenities
# Monkey Room has wifi.

# %%
for cafe in data['results']:
    if 'Open Daily 12:00 AM-11:59 PM' in cafe['hours']['display']:
        print(cafe['name'], "is open 24 hours.")
# Out:
# Bread & Butter is open 24 hours.
# Murray Hill Market is open 24 hours.
# Cafe 53 is open 24 hours.
# The Flame Diner is open 24 hours.
# ABC Cafeteria is open 24 hours.
# Europan Cafe is open 24 hours.
